# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayan04-MCC/google_vit_Proyect/blob/MLP_CUDA/notebooks/mlp_cuda_mnist_enbedings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# !nvcc --version
# Out:
# Tue Jul 15 01:34:03 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
import os

# 🔗 Montar Google Drive
drive.mount('/content/drive')

# 📂 Ruta esperada donde colocaste los archivos CSV
data_dir = "/content/drive/MyDrive/MLP-CUDA/data"

# 📋 Verificar archivos esperados
expected_files = [
    "vit_mnist_train_embeddings.csv",
    "vit_mnist_train_labels.csv",
    "vit_mnist_test_embeddings.csv",
    "vit_mnist_test_labels.csv"
]

print("\n📁 Verificando archivos en:", data_dir)
for filename in expected_files:
    path = os.path.join(data_dir, filename)
    if os.path.exists(path):
        print(f"✅ Encontrado: {filename}")
    else:
        print(f"❌ FALTA: {filename}")
# Out:
# Mounted at /content/drive
#
# 📁 Verificando archivos en: /content/drive/MyDrive/MLP-CUDA/data
# ✅ Encontrado: vit_mnist_train_embeddings.csv
# ✅ Encontrado: vit_mnist_train_labels.csv
# ✅ Encontrado: vit_mnist_test_embeddings.csv
# ✅ Encontrado: vit_mnist_test_labels.csv

# %%
# !rm -r MLP-CUDA/

# %%
# !git clone https://github.com/hyanquiv/MLP-CUDA.git
# Out:
# Cloning into 'MLP-CUDA'...
# remote: Enumerating objects: 126, done.
# remote: Counting objects: 100% (126/126), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 126 (delta 77), reused 84 (delta 39), pack-reused 0 (from 0)
# Receiving objects: 100% (126/126), 11.27 MiB | 20.14 MiB/s, done.
# Resolving deltas: 100% (77/77), done.

# %%
# !make -C MLP-CUDA
# Out:
# make: Entering directory '/content/MLP-CUDA'
# nvcc -std=c++11 -O3 -arch=sm_75   -Iinclude -c src/main.cu -o src/main.o
# nvcc -std=c++11 -O3 -arch=sm_75   -Iinclude -c src/data_loader.cu -o src/data_loader.o
# nvcc -std=c++11 -O3 -arch=sm_75   -Iinclude -c src/mlp_cuda.cu -o src/mlp_cuda.o
# nvcc -std=c++11 -O3 -arch=sm_75   -Iinclude -c src/activation.cu -o src/activation.o
# nvcc -std=c++11 -O3 -arch=sm_75   -Iinclude -c src/cuda_utils.cu -o src/cuda_utils.o
# nvcc -std=c++11 -O3 -arch=sm_75   -Iinclude -c src/train.cu -o src/train.o
# nvcc -std=c++11 -O3 -arch=sm_75   -Iinclude src/main.o src/data_loader.o src/mlp_cuda.o src/activation.o src/cuda_utils.o src/train.o -o build/mnist_mlp -lcublas -lcurand
# make: Leaving directory '/content/MLP-CUDA'

# %%
# !./MLP-CUDA/build/mnist_mlp
# Out:
# Iniciando programa de entrenamiento de MLP con embeddings ViT desde CSV
# ...
#
# 📂 Cargando conjunto de entrenamiento desde CSV...
# 📂 Cargando conjunto de prueba desde CSV...
#
# ✅ Datos cargados exitosamente:
#  - Muestras de entrenamiento: 60000
#  - Muestras de prueba: 10000
#  - Tamaño de embedding (input size): 768
#
# ⚙️ Normalizando datos (opcional)...
#
# 🚧 Creando modelo MLP...
#
# 🚀 Iniciando entrenamiento...
# Iniciando entrenamiento...
# Configuración:
#  - Épocas: 10
#  - Tamaño de lote: 64
#  - Tasa de aprendizaje: 0.001
#  - Muestras de entrenamiento: 60000
#  - Muestras de prueba: 10000
#
# Época 1/10
# Evaluación completada.
# Evaluación completada.
#
# Resumen Época 1:
#   Pérdida: 0.2676
#   Precisión Entrenamiento: 95.48%
#   Precisión Prueba: 95.47%
#
# Época 2/10
# Evaluación completada.
# Evaluación completada.
#
# Resumen Época 2:
#   Pérdida: 0.1319
#   Precisión Entrenamiento: 96.40%
#   Precisión Prueba: 96.30%
#
# Época 3/10
# Evaluación completada.
# ...
